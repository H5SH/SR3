# %%
pip install torch
# Out:
# Requirement already satisfied: torch in c:\conda\envs\sr3\lib\site-packages (2.4.0)
# Requirement already satisfied: filelock in c:\conda\envs\sr3\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\conda\envs\sr3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\conda\envs\sr3\lib\site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in c:\conda\envs\sr3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\conda\envs\sr3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\conda\envs\sr3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\conda\envs\sr3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\conda\envs\sr3\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\conda\envs\sr3\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from math import log

# %%
class AttnBlock(nn.Module):
    def __init__(self, embedding_dims, num_heads = 4)-> None:
        super().__init__()
        
        self.embedding_dims = embedding_dims
        self.ln = nn.LayerNorm(embedding_dims)
        self.mhsa = MultiHeadSelfAttention(embedding_dims = embedding_dims, num_heads = num_heads)
        self.ff = nn.Sequential(
            nn.LayerNorm(self.embedding_dims),
            nn.Linear(self.embedding_dims, self.embedding_dims),
            nn.GELU(),
            nn.Linear(self.embedding_dims, self.embedding_dims)
        )
        
    def forward(self, x):
        bs, c, sz, _ = x.shape
        x = x.view(-1, self.embedding_dims, sz * sz).swapaxes(1, 2) # is of the shape (bs, sz**2, self.embedding_dims)
        x_ln = self.ln(x)
        _, attention_value = self.mhsa(x_ln, x_ln, x_ln)
        attention_value = attention_value + x
        attention_value = self.ff(attention_value) + attention_value
        return attention_value.swapaxes(2, 1).view(-1, c, sz, sz)

# %%
class MultiHeadSelfAttention(nn.Module):
    def __init__(self, embedding_dims, num_heads = 4)-> None:
        super().__init__()
        self.embedding_dims = embedding_dims
        self.num_heads = num_heads
        assert self.embedding_dims % self.num_heads == 0, f"{self.embedding_dims} not divisible by {self.num_heads}"
        self.head_dim = self.embedding_dims // self.num_heads
        self.wq = nn.Linear(self.head_dim, self.head_dim)
        self.wk = nn.Linear(self.head_dim, self.head_dim)
        self.wv = nn.Linear(self.head_dim, self.head_dim)
        self.wo = nn.Linear(self.embedding_dims, self.embedding_dims)
    
    def attention(self, q, k, v):
        # no need for a mask
        attn_weights = F.softmax((q @ k.transpose(-1, -2))/self.head_dim**0.5, dim = -1)
        return attn_weights, attn_weights @ v
    
    def forward(self, q, k, v):
        bs, img_sz, c = q.shape
        q = q.view(bs, img_sz, self.num_heads, self.head_dim).transpose(1, 2)
        k = k.view(bs, img_sz, self.num_heads, self.head_dim).transpose(1, 2)
        v = v.view(bs, img_sz, self.num_heads, self.head_dim).transpose(1, 2)
        # q, k, v of the shape (bs, self.num_heads, img_sz**2, self.heading_dim)
        q = self.wq(q)
        k = self.wk(k)
        v = self.wv(v)
        
        attn_weights, o = self.attention(q, k, v) # of shape (bs, num_heads, img_sz**2, c)
        o = o.transpose(1, 2).contiguous().view(bs, img_sz, self.embedding_dims)
        o = self.wo(o)
        return attn_weights, o

# %%
# Encoder Block for downsampling
class encoder_block(nn.Module):
    def __init__(self, in_c, out_c, time_steps, activation = 'relu'):
        super().__init__()
        self.conv = conv_block(in_c, out_c, time_steps = time_steps, activation = activation, embedding_dims = out_c)
        self.pool = nn.MaxPool2d((2, 2))
        
    def forward(self, inputs, time = None):
        x = self.conv(inputs, time)
        p = self.pool(x)
        return x, p

# Decoder Block for upsampling
class decoder_block(nn.Module):
    def __init__(self, in_c, out_c, time_steps, activation = 'relu'):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c, out_c, kernel_size=2, stride=2, padding=0)
        self.conv = conv_block(out_c+out_c, out_c, time_steps = time_steps, activation = activation, embedding_dims = out_c)
    
    def forward(self, inputs, skip, time = None):
        x = self.up(inputs)
        x = torch.cat([x, skip], axis=1)
        x = self.conv(x, time)
        return x

# %% [markdown]
# ### convolution block that supports taking in ‘gamma’ or timestep ‘t’.

# %%
# based on https://github.com/lmnt-com/wavegrad/blob/master/src/wavegrad/model.py#L34

class GammaEncoding(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
        self.linear = nn.Linear(dim, dim)
        self.act = nn.LeakyReLU()
        
    def forward(self, noise_level):
        count = self.dim // 2
        step = torch.arange(count, dtype=noise_level.dtype, device=noise_level.device) / count
        encoding = noise_level.unsqueeze(1) * torch.exp(log(1e4) * step.unsqueeze(0))
        encoding = torch.cat([torch.sin(encoding), torch.cos(encoding)], dim=-1)
        return self.act(self.linear(encoding))
    
    # Double Conv Block
class conv_block(nn.Module):
    
    def __init__(self, in_c, out_c, time_steps = 1000, activation = 'relu', embedding_dims = None):
        super().__init__()
        
        self.conv1 = nn.Conv2d(in_c, out_c, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_c)
        
        self.conv2 = nn.Conv2d(out_c, out_c, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_c)
        self.embedding_dims = embedding_dims if embedding_dims else out_c
    
        # self.embedding = nn.Embedding(time_steps, embedding_dim = self.embedding_dims)
        self.embedding = GammaEncoding(self.embedding_dims)
        # switch to nn.Embedding if you want to pass in timesteo instead; but note that it should be of dtype torch.long
        self.act = nn.ReLU() if activation == 'relu' else nn.SiLU()
    
    def forward(self, inputs, time = None):
        time_embedding = self.embedding(time).view(-1, self.embedding_dims, 1, 1)
        # print(f"time embed shape => {time_embedding.shape}")
        x = self.conv1(inputs)
        x = self.bn1(x)
        x = self.act(x)
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.act(x)
        x = x + time_embedding
        return x

# %% [markdown]
# ### Diffusion Model

# %%
class UNet(nn.Module):
    def __init__(self, input_channels = 3, output_channels = 3, time_steps = 512):
        super().__init__()
        self.input_channels = input_channels
        self.output_channels = output_channels
        self.time_steps = time_steps
        
        self.e1 = encoder_block(self.input_channels, 64, time_steps = self.time_steps)
        self.e2 = encoder_block(64,128, time_steps=self.time_steps)
        self.da2 = AttnBlock(128)
        self.e3 = encoder_block(128, 256, time_steps=self.time_steps)
        self.da3 = AttnBlock(256)
        self.e4 = encoder_block(256, 512, time_steps=self.time_steps)
        self.da4 = AttnBlock(512)
        
        self.b = conv_block(512, 1024, time_steps=self.time_steps) # bottleneck
        self.ba1 = AttnBlock(1024)
        self.d1 = decoder_block(1024, 512, time_steps=self.time_steps)
        self.ua1 = AttnBlock(512)
        self.d2 = decoder_block(512, 256, time_steps=self.time_steps)
        self.ua2 = AttnBlock(256)
        self.d3 = decoder_block(256, 128, time_steps=self.time_steps)
        self.ua3 = AttnBlock(128)
        self.d4 = decoder_block(128, 64, time_steps=self.time_steps)
        self.ua4 = AttnBlock(64)
        self.outputs = nn.Conv2d(64, self.output_channels, kernel_size=1, padding=0)
        
    def forward(self, inputs, t = None):
        # downsampling block
        s1, p1 = self.e1(inputs, t)
        s2, p2 = self.e2(p1, t)
        s3, p3 = self.e3(p2, t)
        p3 = self.da3(p3)
        s4, p4 = self.e4(p3, t)
        p4 = self.da4(p4)
        # bottleneck
        b = self.b(p4, t)
        b = self.ba1(b)
        # upsampling block
        d1 = self.d1(b, s4, t)
        d1 = self.ua1(d1)
        d2 = self.d2(d1, s3, t)
        d2 = self.ua2(d2)
        d3 = self.d3(d2, s2, t)
        d3 = self.ua3(d3)
        d4 = self.d4(d3, s1, t)
        d4 = self.ua4(d4)
        outputs = self.outputs(d4)
        return outputs

# %%
class DiffusionModel(nn.Module):
    def __init__(self, time_steps,
                beta_start = 10e-4,
                beta_end = 0.02,
                image_dims = (3, 128, 128)):
        super().__init__()
        self.time_steps = time_steps
        self.image_dims = image_dims
        c, h, w = self.image_dims
        self.img_size, self.input_channels = h, c
        self.betas = torch.linspace(beta_start, beta_end, self.time_steps)
        self.alphas = 1 - self.betas
        self.alpha_hats = torch.cumprod(self.alphas, dim = -1)
        self.model = UNet(input_channels = 2*c, output_channels = c, time_steps = self.time_steps)
    
    def add_noise(self, x, ts):
        # 'x' and 'ts' are expected to be batched
        noise = torch.randn_like(x)
        # print(x.shape, noise.shape)
        noised_examples = []
        for i, t in enumerate(ts):
            alpha_hat_t = self.alpha_hats[t]
            noised_examples.append(torch.sqrt(alpha_hat_t) * x[i] + torch.sqrt(1 - alpha_hat_t)*noise[i])
        return torch.stack(noised_examples), noise
    
    def forward(self, x, t):
        return self.model(x, t)

# %% [markdown]
# ## Defining U-Net with Self-Attention

# %% [markdown]
# # DATASET PREPARATION

# %%
# import os

# base_path = '/kaggle/input/nature/Nature/x128'
# common_path = '/kaggle/working/'

# classes = os.listdir(base_path)
# class_paths = [os.path.join(base_path, _class) for _class in classes]

# print(classes)
# print(class_paths)
# Out:
# ['Mountain', 'Lake', 'Fire', 'City']
# ['/kaggle/input/nature/Nature/x128/Mountain', '/kaggle/input/nature/Nature/x128/Lake', '/kaggle/input/nature/Nature/x128/Fire', '/kaggle/input/nature/Nature/x128/City']

# %%
# for _class_path in class_paths:
# _class_path = class_paths[0]
# images = os.listdir(_class_path)
# _class = _class_path.split('/')[-1]
# for image in images:
#     preimg = os.path.join(_class_path, image)
#     postimg = os.path.join(common_path, f"{_class}_{image}")
#     os.system(f"mv {preimg} {postimg}")
# Out:
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13854.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6526.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22297.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4038.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23944.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22781.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5540.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21627.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17407.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22276.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21437.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7196.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21482.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17067.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6665.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2897.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13955.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16782.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9008.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17821.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14425.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19655.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18804.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6676.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9597.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4300.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16920.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6010.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12932.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20197.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/885.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2789.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11098.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10146.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1327.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15265.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6242.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1781.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4749.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7750.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4077.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10799.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24126.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15058.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21974.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3318.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19666.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11509.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16633.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7135.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18646.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23133.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6362.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13891.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/151.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13595.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6608.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1097.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4307.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23868.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4526.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9595.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9768.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18851.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2552.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23769.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3011.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20757.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8334.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1376.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24584.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2655.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6078.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6437.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24266.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16084.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14364.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14874.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6176.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19088.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15053.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3164.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22064.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16477.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15362.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6591.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10348.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/426.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2204.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16292.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/732.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13305.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4228.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18491.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3887.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10777.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19885.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15017.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12440.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23096.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19272.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17753.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7308.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7977.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15096.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16763.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15630.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19221.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23033.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/503.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21549.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16467.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20575.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13609.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21564.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17133.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12539.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5777.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9708.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17731.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21253.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19723.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9897.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22041.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2573.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18149.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16339.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13134.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6705.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7627.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8465.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1297.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7961.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2011.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15007.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22771.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8011.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14216.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22848.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18032.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/641.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/892.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10844.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17292.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9073.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2131.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23487.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1478.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13394.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7274.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6340.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20422.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24757.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4635.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22296.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23551.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2471.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4277.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16616.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1413.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14341.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4306.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11771.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12823.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18968.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1604.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14840.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20836.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15506.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20362.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2476.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22371.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21717.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2984.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21821.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14599.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9101.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9184.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10635.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24263.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6666.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2928.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16041.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12554.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13198.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2470.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22080.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22617.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19025.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2608.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17835.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2595.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21757.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15917.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22462.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/988.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18953.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10284.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4357.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13248.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20981.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7098.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22197.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16901.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11576.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13441.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24369.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20399.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/622.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6895.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9215.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1129.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23726.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19599.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17660.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18121.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17644.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2501.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17583.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18743.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4825.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20282.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6130.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10397.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21214.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2323.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14362.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17401.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14111.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10418.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2627.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23429.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11670.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9109.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23978.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12593.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17991.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14633.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19924.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20179.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4743.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15587.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8410.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16565.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1655.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13061.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9641.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4447.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16646.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22537.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16191.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3755.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9374.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6124.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13221.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7316.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20705.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15388.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13240.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7521.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20025.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3730.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14206.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9316.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11294.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12027.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6529.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12180.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17434.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16181.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2795.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9430.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8225.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1144.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5600.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6098.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10179.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8511.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14429.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24890.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16172.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9404.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/440.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4853.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/260.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6171.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13619.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19302.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8858.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8973.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13962.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12313.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13771.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1716.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3522.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8414.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3620.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9335.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21490.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19970.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23760.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5229.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24034.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20331.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18922.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8590.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8124.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17549.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24537.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11979.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6430.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3037.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3305.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19734.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11162.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13926.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8313.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12446.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7924.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21735.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12014.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4539.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15768.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18665.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19202.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17779.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8191.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16891.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19110.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12184.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20842.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10933.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20246.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23668.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12794.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18367.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13028.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3284.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24174.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17400.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3243.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2282.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/534.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6540.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3395.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11846.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4066.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7375.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12552.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21125.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14494.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3302.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7303.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12659.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/202.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3726.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20354.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8526.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23739.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6963.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4525.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4338.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9269.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/84.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4008.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4004.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13846.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11002.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22672.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21143.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21066.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15792.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20425.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4295.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21580.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24826.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16050.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/577.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24177.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3768.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22260.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18706.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10897.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7106.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23568.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6524.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/751.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11813.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23246.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17451.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6784.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4074.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2698.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8891.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24220.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6557.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/944.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7653.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23434.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5437.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6087.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18928.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22870.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7304.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18346.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20546.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23720.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12125.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16536.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3623.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/237.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/273.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18578.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6472.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4215.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12690.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/286.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15311.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11640.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10785.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13851.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24648.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21111.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1032.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14303.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5759.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14138.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6635.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15043.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6533.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22970.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16971.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17527.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9594.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16886.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20667.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17330.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4742.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7584.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15806.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15225.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6047.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4027.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20275.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15798.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19443.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16409.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10978.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8293.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24137.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3218.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19170.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4578.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18765.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23933.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/283.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12664.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8398.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7813.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24338.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/486.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22457.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8436.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2338.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12629.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5970.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17972.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16452.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14703.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/513.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10976.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6764.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13608.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9068.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10353.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11074.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17538.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8115.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7884.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4882.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8361.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11759.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13580.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24651.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17525.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15187.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11898.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20466.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15178.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13267.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21233.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10427.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10774.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17898.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3461.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/766.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2460.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/85.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5212.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22827.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23742.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4715.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21540.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22411.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12030.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16398.jpg': Read-only file system
# ...
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15398.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22157.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10742.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23513.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24044.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17616.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/651.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6720.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13905.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17919.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2123.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12433.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15196.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22289.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10694.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1544.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24816.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11164.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4383.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1324.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4513.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7112.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9691.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11363.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14817.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4671.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2886.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2705.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24432.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11487.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14123.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17196.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16560.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23039.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17358.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7230.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12714.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19872.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5269.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22225.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2099.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3184.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15635.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23473.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13001.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8126.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4816.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20325.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20012.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24604.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/99.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11773.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16778.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15182.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7259.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7377.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16295.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22136.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10756.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19867.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11818.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11779.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13963.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8936.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2155.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7896.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4260.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19304.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22545.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22688.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12746.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11551.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14799.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15881.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6164.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23832.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16636.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22467.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12610.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17748.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15803.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15455.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17418.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7539.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8025.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8913.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7372.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17635.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16966.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9422.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24135.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17982.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18095.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23262.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9671.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19887.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3359.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11573.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15421.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4875.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13271.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10552.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16031.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16630.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16751.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/17263.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1563.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20238.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2264.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10667.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13596.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6746.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5305.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8350.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23552.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22676.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10287.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/10188.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20805.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1607.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24781.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24919.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20080.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/14204.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13815.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19562.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13225.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11548.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19426.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12863.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11873.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23860.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18281.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/20155.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16022.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15518.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16921.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/13116.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3269.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19724.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8383.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/382.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1523.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/21288.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/5981.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23816.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/1625.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9312.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/19083.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/7633.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/3201.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/23869.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/4080.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8067.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18802.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/15870.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/6354.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/24861.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/12192.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/836.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18747.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8863.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/22379.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/9738.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/2255.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/8579.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/11344.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/18404.jpg': Read-only file system
# mv: cannot remove '/kaggle/input/nature/Nature/x128/Mountain/16038.jpg': Read-only file system

# %%
from torchvision.transforms import InterpolationMode
from torchvision.transforms import transforms
import os, cv2
from torch.utils.data import Dataset, DataLoader

# %%
class SRDataset(Dataset):
    def __init__(self, dataset_path, limit = -1, _transforms=None, hr_sz = 32, lr_sz = 32) -> None:
        super().__init__()
        
        self.transforms = _transforms
        
        if not self.transforms:
            self.transforms = transforms.Compose([
                transforms.ToTensor(),
                transforms.RandomHorizontalFlip(p = 0.5),
                transforms.ColorJitter([0.5, 1]),
                transforms.RandomAdjustSharpness(1.1, p=0.4),
                transforms.Normalize((0.5), (0.5)) # normalizing image with mean, std = 0.5, 0.5
            ])
        self.hr_sz, self.lr_sz = transforms.Resize((hr_sz, hr_sz),  interpolation = InterpolationMode.BICUBIC), transforms.Resize((lr_sz, lr_sz), interpolation = InterpolationMode.BICUBIC)
        
        self.dataset_path, self.limit = dataset_path, limit
        self.valid_extensions = ["jpg", "jpeg", 'png', "JPEG", "JPG"]
        
        self.images_path = dataset_path
        self.images = os.listdir(self.images_path)[:self.limit]
        self.images = [os.path.join(self.images_path, image) for image in self.images if image.split('.')[-1] in self.valid_extensions]
        
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, index):
        image = cv2.imread(self.images[index])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = self.transforms(image)
        hr_image, lr_image = self.hr_sz(image), self.lr_sz(image)
        # the core idea here is resizing the (128, 128) down to a lower resolution and then back up to (128, 128)
        return self.hr_sz(lr_image), hr_image # the hr_image is 'y' and low res image scaled to (128, 128) is our 'x'

# %% [markdown]
# ## Training

# %%
from time import time 

def train_ddpm(time_steps = 2000, epochs = 1, batch_size = 16, device = "cuda", image_dims = (3, 128, 128), low_res_dims = (3, 32, 32)):
#     torch.cuda.empty_cache()
    ddpm = DiffusionModel(time_steps = time_steps)
    c, hr_sz, _ = image_dims
    _, lr_sz, _ = low_res_dims
    
    ds = SRDataset('/kaggle/working/', hr_sz = hr_sz, lr_sz = lr_sz, limit = 1000)
    loader = DataLoader(ds, batch_size = batch_size, shuffle = True, drop_last = True, num_workers = 2)
    
    opt = torch.optim.Adam(ddpm.model.parameters(), lr = 1e-3)
    criterion = nn.MSELoss(reduction='mean')
    
    ddpm.model.to()
    print()
    for ep in range(epochs):
        ddpm.model.train()
        print(f"Epoch {ep}:")
        losses = []
        stime = time()
        
        for i, (x, y) in enumerate(loader):
            # 'y' represents the high-resolution target image, while 'x' represents the low-resolution image to be conditioned upon.
            
            bs = y.shape[0]
            x, y = x.to(), y.to()
            
            ts = torch.randint(low = 1, high = ddpm.time_steps, size = (bs, ))
            gamma = ddpm.alpha_hats[ts].to()
            ts = ts.to()
            
            y, target_noise = ddpm.add_noise(y, ts)
            y = torch.cat([x, y], dim = 1)
            
            predicted_noise = ddpm.model(y, gamma)
            loss = criterion(target_noise, predicted_noise)
            
            opt.zero_grad()
            loss.backward()
            opt.step()
            
            losses.append(loss.item())
            
            if i % 250 == 0:
                print(f"Loss: {loss.item()}; step {i}; epoch {ep}")
            
        ftime = time()
        print(f"Epoch trained in {ftime - stime}s; Avg loss => {sum(losses)/len(losses)}")
        
        torch.save(ddpm.state_dict(), f"./sr_ep_{ep}.pt")
        print()
# train_ddpm()
